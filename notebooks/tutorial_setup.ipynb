# %% [markdown]
# # Gammapy tutorial setup
#
# This notebook explains how to get set up to execute the Gammapy tutorials locally on your machine.
#
# ## Short version
#
# If you're familiar with git, Python, Jupyter notebooks and you're using conda, here's the short version of the commands you need to execute to get set up.
#
# Go to some location where you have ~ 1 GB of disk space:
# ```
# cd <scratch>
# ```
#
# Install some dependencies:
# ```
# conda install -c astropy regions
# conda install -c sherpa sherpa
# ```
#
# Install the development version of Gammapy (the latest and greatest!):
# ```
# git clone https://github.com/gammapy/gammapy.git
# cd gammapy
# python -m pip install .
# ```
#
# Get the `gammapy-extra` repo with example datasets and the notebooks:
# ```
# cd ..
# git clone https://github.com/gammapy/gammapy-extra.git
# export GAMMAPY_EXTRA=$PWD/gammapy-extra
# cd gammapy-extra/notebooks
# ```
#
# Start the notebooks using one of the following commands (depends a bit on how you installed it):
# ```
# jupyter-notebook
# jupyter notebook
# ipython notebook
# ```
#
# ## Check
#
# To check if you're set up
# ```
# import gammapy
# print(gammapy)
# print(gammapy.__version__)
# ```
#
# ## Detailed version
#
# tbd
#
#
# 1. Install a scientific Python stack (Numpy, Scipy, Astropy). There's several options to do this, if you're not sure, we recommend you use conda. There's a bit of information about Anaconda and Miniconda and download links [here](http://nbviewer.jupyter.org/github/jakevdp/WhirlwindTourOfPython/blob/master/00-Introduction.ipynb#Installation-with-conda).
#   * To check if this step worked:
#   ```
#   which python
#   which ipython
#
#
# 1. Get and install Gammapy. Detailed information is given in the [Gammapy installation instructions](http://docs.gammapy.org/en/latest/install.html), there's a few
#
# * To run the tutorials locally and do the exercises, install Jupyter, IPython  and then get the [gammapy-extra](https://github.com/gammapy/gammapy-extra) repo (either via git or as a zip file) and then go to the `notebooks` folder in a terminal and type one of the following commands (how to start Jupyter notebook is a little different depending on how you installed it):
